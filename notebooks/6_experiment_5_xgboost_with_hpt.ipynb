# %%
import mlflow
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Exp 5 - ML Algos with HP Tuning")
# Out:
# 2026/06/20 10:13:39 INFO mlflow.tracking.fluent: Experiment with name 'Exp 5 - ML Algos with HP Tuning' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/5', creation_time=1781930619074, experiment_id='5', last_update_time=1781930619074, lifecycle_stage='active', name='Exp 5 - ML Algos with HP Tuning', tags={}, trace_location=None, workspace='default'>

# %%
import optuna
import mlflow
import mlflow.sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('../data/reddit_preprocessing.csv').dropna()
df.shape
# Out:
# (36662, 2)

# %%
df['category'] = df['category'].map({-1: 2, 0: 0, 1: 1})

df = df.dropna(subset=['category'])

ngram_range = (1, 3)
max_features = 10000

X_train, X_test, y_train, y_test = train_test_split(df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category'])

vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=max_features)
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

smote = SMOTE(random_state=42)
X_train_vec, y_train = smote.fit_resample(X_train_vec, y_train)

def log_mlflow(model_name, model, X_train, X_test, y_train, y_test):
    with mlflow.start_run():
        mlflow.set_tag("mlflow.runName", f"{model_name}_SMOTE_TFIDF_Trigrams")
        mlflow.set_tag("experiment_type", "algorithm_comparison")

        mlflow.log_param("algo_name", model_name)

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        mlflow.sklearn.log_model(model, f"{model_name}_model")


def objective_xgboost(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True)
    max_depth = trial.suggest_int('max_depth', 3, 10)

    model = XGBClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth, random_state=42)
    return accuracy_score(y_test, model.fit(X_train_vec, y_train).predict(X_test_vec))


def run_optuna_experiment():
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_xgboost, n_trials=30)

    best_params = study.best_params
    best_model = XGBClassifier(n_estimators=best_params['n_estimators'], learning_rate=best_params['learning_rate'], max_depth=best_params['max_depth'], random_state=42)

    log_mlflow("XGBoost", best_model, X_train_vec, X_test_vec, y_train, y_test)

run_optuna_experiment()
# Out:
# [I 2026-06-20 10:14:15,568] A new study created in memory with name: no-name-35743146-d0f3-4506-817f-419a617f01b2
# [I 2026-06-20 10:15:36,849] Trial 0 finished with value: 0.5917087140324561 and parameters: {'n_estimators': 64, 'learning_rate': 0.0001327618092615547, 'max_depth': 8}. Best is trial 0 with value: 0.5917087140324561.
# [I 2026-06-20 10:18:42,506] Trial 1 finished with value: 0.5866630301377336 and parameters: {'n_estimators': 190, 'learning_rate': 0.00010173933666558657, 'max_depth': 8}. Best is trial 0 with value: 0.5917087140324561.
# [I 2026-06-20 10:20:02,989] Trial 2 finished with value: 0.5863902904677485 and parameters: {'n_estimators': 230, 'learning_rate': 0.002309669711065941, 'max_depth': 5}. Best is trial 0 with value: 0.5917087140324561.
# [I 2026-06-20 10:21:12,272] Trial 3 finished with value: 0.7192145097504432 and parameters: {'n_estimators': 82, 'learning_rate': 0.06356503780178696, 'max_depth': 8}. Best is trial 3 with value: 0.7192145097504432.
# [I 2026-06-20 10:22:26,374] Trial 4 finished with value: 0.6814400654575208 and parameters: {'n_estimators': 106, 'learning_rate': 0.03125001208047581, 'max_depth': 7}. Best is trial 3 with value: 0.7192145097504432.
# [I 2026-06-20 10:25:22,381] Trial 5 finished with value: 0.6367107595799809 and parameters: {'n_estimators': 198, 'learning_rate': 0.0042035798332936206, 'max_depth': 8}. Best is trial 3 with value: 0.7192145097504432.
# [I 2026-06-20 10:26:30,287] Trial 6 finished with value: 0.591435974362471 and parameters: {'n_estimators': 102, 'learning_rate': 0.0034619827662098206, 'max_depth': 7}. Best is trial 3 with value: 0.7192145097504432.
# [I 2026-06-20 10:27:29,060] Trial 7 finished with value: 0.5236601663711987 and parameters: {'n_estimators': 237, 'learning_rate': 0.00011820075037883169, 'max_depth': 4}. Best is trial 3 with value: 0.7192145097504432.
# [I 2026-06-20 10:27:56,421] Trial 8 finished with value: 0.576980771853266 and parameters: {'n_estimators': 53, 'learning_rate': 0.004987901626236247, 'max_depth': 6}. Best is trial 3 with value: 0.7192145097504432.
# [I 2026-06-20 10:29:45,118] Trial 9 finished with value: 0.6358925405700259 and parameters: {'n_estimators': 87, 'learning_rate': 0.0035169783075413236, 'max_depth': 10}. Best is trial 3 with value: 0.7192145097504432.
# [I 2026-06-20 10:30:23,904] Trial 10 finished with value: 0.7298513568798581 and parameters: {'n_estimators': 289, 'learning_rate': 0.061974457192429874, 'max_depth': 3}. Best is trial 10 with value: 0.7298513568798581.
# [I 2026-06-20 10:31:01,642] Trial 11 finished with value: 0.7550797763534706 and parameters: {'n_estimators': 295, 'learning_rate': 0.09478912552684675, 'max_depth': 3}. Best is trial 11 with value: 0.7550797763534706.
# [I 2026-06-20 10:31:39,286] Trial 12 finished with value: 0.7576708032183281 and parameters: {'n_estimators': 299, 'learning_rate': 0.09849193491023303, 'max_depth': 3}. Best is trial 12 with value: 0.7576708032183281.
# [I 2026-06-20 10:32:20,820] Trial 13 finished with value: 0.6637119869084959 and parameters: {'n_estimators': 285, 'learning_rate': 0.021137248504257893, 'max_depth': 3}. Best is trial 12 with value: 0.7576708032183281.
# [I 2026-06-20 10:33:06,784] Trial 14 finished with value: 0.7691258693576981 and parameters: {'n_estimators': 258, 'learning_rate': 0.09856566120916681, 'max_depth': 4}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:34:27,596] Trial 15 finished with value: 0.6701213691531434 and parameters: {'n_estimators': 250, 'learning_rate': 0.014368922122233072, 'max_depth': 5}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:35:25,830] Trial 16 finished with value: 0.6507568525842083 and parameters: {'n_estimators': 261, 'learning_rate': 0.01240136902845683, 'max_depth': 4}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:36:08,831] Trial 17 finished with value: 0.6927587617618983 and parameters: {'n_estimators': 203, 'learning_rate': 0.03601644474912969, 'max_depth': 4}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:36:50,228] Trial 18 finished with value: 0.7503068321287332 and parameters: {'n_estimators': 156, 'learning_rate': 0.09788179330052714, 'max_depth': 5}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:37:52,303] Trial 19 finished with value: 0.5453429701350061 and parameters: {'n_estimators': 265, 'learning_rate': 0.0010133843045873135, 'max_depth': 4}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:38:27,294] Trial 20 finished with value: 0.6905768444020183 and parameters: {'n_estimators': 221, 'learning_rate': 0.04272655657627626, 'max_depth': 3}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:39:21,778] Trial 21 finished with value: 0.7524887494886131 and parameters: {'n_estimators': 300, 'learning_rate': 0.08780286585566767, 'max_depth': 3}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:39:57,112] Trial 22 finished with value: 0.7533069684985682 and parameters: {'n_estimators': 275, 'learning_rate': 0.0978338792771616, 'max_depth': 3}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:41:01,897] Trial 23 finished with value: 0.6875767080321833 and parameters: {'n_estimators': 300, 'learning_rate': 0.02292969395292915, 'max_depth': 4}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:42:13,242] Trial 24 finished with value: 0.7387153961543707 and parameters: {'n_estimators': 251, 'learning_rate': 0.04989481051029385, 'max_depth': 5}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:42:55,629] Trial 25 finished with value: 0.6421655529796809 and parameters: {'n_estimators': 276, 'learning_rate': 0.013596775471969023, 'max_depth': 3}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:43:33,821] Trial 26 finished with value: 0.7068048547661258 and parameters: {'n_estimators': 171, 'learning_rate': 0.05346270715544772, 'max_depth': 4}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:45:19,635] Trial 27 finished with value: 0.7134869766807582 and parameters: {'n_estimators': 247, 'learning_rate': 0.026700616286351675, 'max_depth': 6}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:45:53,563] Trial 28 finished with value: 0.5899359061775535 and parameters: {'n_estimators': 217, 'learning_rate': 0.007703729216075911, 'max_depth': 3}. Best is trial 14 with value: 0.7691258693576981.
# [I 2026-06-20 10:46:58,011] Trial 29 finished with value: 0.5417973544252012 and parameters: {'n_estimators': 266, 'learning_rate': 0.0004778140303218448, 'max_depth': 4}. Best is trial 14 with value: 0.7691258693576981.
# 2026/06/20 10:47:48 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/20 10:47:49 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run XGBoost_SMOTE_TFIDF_Trigrams at: http://127.0.0.1:5000/#/experiments/5/runs/afbd1f9720644487805fdda0ce7403bd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5
